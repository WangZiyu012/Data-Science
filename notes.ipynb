# %% [markdown]
# # intro
#
# ## focused
# 1. Learning Python
# 2. Data Science
#
# ## not focused
# 1. OOP
# 2. exception handling
# 3. web development

# %% [markdown]
# # Python basics
#
# assigning data to a variable: based on the value (for example 2 is int), the type of x is set to that type (int). This is called dynamically typed language, which we do not need to specify the type of the variable

# %%
x = 2 # int
xy = 7.2 # float
# %whos
print(type(x))
# Out:
# Variable   Type       Data/Info
# -------------------------------
# x          int        2
# xy         float      7.2
# xyz        str        string
# xyza       complex    (1+2j)
# <class 'int'>

# %%
del x
xyz, xyza = "string", 1+2j
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# xy         float      7.2
# xyz        str        string
# xyza       complex    (1+2j)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Use parents and "not" "and" "or" symbols to link the comparisons, if no parents, the operation oreder is not > and > or

# %% [markdown]
# # Some useful functions in Python

# %% [markdown]
# *round()* function is used to round off a number to a given number of decimal places.

# %%
print(round(3.14159))
print(round(3.14159, 2))
# Out:
# 3
# 3.14

# %% [markdown]
# divmod() # returns a tuple of the quotient and remainder

# %%
divmod(9, 2)
# Out:
# (4, 1)
